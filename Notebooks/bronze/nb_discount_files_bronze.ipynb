# %%
dbutils.widgets.dropdown(name = "environment", defaultValue= "dev",choices= ["dev","prd","qa"],label = "select Environment")
env = dbutils.widgets.get("environment")
# print(env)

# %%
tablName = f"saleslake_{env}.bronze_{env}.rawDiscount"
# print(tablName)
srcFileLoc=f"/Volumes/saleslake_{env}/bronze_{env}/vol_saleslake_src_files_{env}/manual_discount/"
# print(srcFileLoc)

# %%
dfDiscount = spark.read.option("inferSchema", "false").option('header','true').csv(srcFileLoc)

dfDiscount.write.mode("append").saveAsTable(f"{tablName}")
spark.sql(f"select * from {tablName}").display()
# f"tablName".display()
# /Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/

# %%
# AWS, GCP, AZURE

# srcLoc ='/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/'

# arcLoc ='/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_discount/'


# listofFiles=dbutils.fs.ls(srcLoc)
# print(listofFiles)

# for file in listofFiles:
#   print('FileName:',file.name)
#   print('FileSize:',file.size)

# DBTITLE 1,Move Files to Archive
# for file in dbutils.fs.ls(srcLoc):
#   print(file.name)
#   dbutils.fs.mv(srcLoc+file.name,arcLoc+

# %%
# dbutils.fs.mv(srcLoc,arcLoc,recurse=True)

# %%
# srcLoc ='/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/'

# arcLoc ='/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_discount/'

# listofFiles=dbutils.fs.ls(srcLoc)

# for file in listofFiles:
#     print(file.name)
#     if file.name.endswith('.csv'):
#         dbutils.fs.mv(srcLoc+file.name,arcLoc+file.name)
#     # dbutils.fs.mv(srcLoc+file.name,arcLoc+

# %%
# dbutils.fs.cp ---> Copy the files
# dbutils.fs.  --->
