-- %%
------------- Create all Catalog & Schemas -------------------
CREATE CATALOG IF NOT EXISTS saleslake_dev;
CREATE CATALOG IF NOT EXISTS saleslake_qa;
CREATE CATALOG IF NOT EXISTS saleslake_prd;

------------- dev Schema ------------
CREATE SCHEMA IF NOT EXISTS saleslake_dev.bronze_dev;
CREATE SCHEMA IF NOT EXISTS saleslake_dev.silver_dev;
CREATE SCHEMA IF NOT EXISTS saleslake_dev.gold_dev;

------------- qa Schema ------------
CREATE SCHEMA IF NOT EXISTS saleslake_qa.bronze_qa;
CREATE SCHEMA IF NOT EXISTS saleslake_qa.silver_qa;
CREATE SCHEMA IF NOT EXISTS saleslake_qa.gold_qa;

------------- prd Schema ------------
CREATE SCHEMA IF NOT EXISTS saleslake_prd.bronze_prd;
CREATE SCHEMA IF NOT EXISTS saleslake_prd.silver_prd;
CREATE SCHEMA IF NOT EXISTS saleslake_prd.gold_prd;

------------- Source File Location Volumn dev,qa,prd  ------------
CREATE VOLUME IF NOT EXISTS saleslake_dev.bronze_dev.vol_saleslake_src_files_dev;
CREATE VOLUME IF NOT EXISTS saleslake_qa.bronze_qa.vol_saleslake_src_files_qa;
CREATE VOLUME IF NOT EXISTS saleslake_prd.bronze_prd.vol_saleslake_src_files_prd;

------------- Archival File Location Volumn dev,qa,prd  ------------
CREATE VOLUME IF NOT EXISTS saleslake_dev.bronze_dev.vol_saleslake_archive_files_dev;
CREATE VOLUME IF NOT EXISTS saleslake_qa.bronze_qa.vol_saleslake_archive_files_qa;
CREATE VOLUME IF NOT EXISTS saleslake_prd.bronze_prd.vol_saleslake_archive_files_prd;


--------------------

----------------------- 1. Bronze layer Tables -------------------------
------------1. Select Customer ---------------------
-- SELECT * FROM saleslake_dev.bronze_dev.rawCustomer;
-- SELECT * FROM saleslake_qa.bronze_qa.rawCustomer;
-- SELECT * FROM saleslake_prd.bronze_prd.rawCustomer;
------------1. Create Customer ---------------------
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

----------------------- Bronze layer Tables -------------------------
------------2. Select Discount  ---------------------
-- SELECT * FROM saleslake_dev.bronze_dev.rawDiscount;
-- SELECT * FROM saleslake_qa.bronze_qa.rawDiscount;
-- SELECT * FROM saleslake_prd.bronze_prd.rawDiscount;

------------2. Select Discount ---------------------
CREATE TABLE saleslake_dev.bronze_dev.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING

);

CREATE TABLE saleslake_qa.bronze_qa.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING

);

CREATE TABLE saleslake_prd.bronze_prd.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING

);

----------------------- Bronze layer Tables -------------------------

------------Bronze Sales ---------------------
------------3. Select Sales  ---------------------
-- SELECT * FROM saleslake_dev.bronze_dev.rawsales;
-- SELECT * FROM saleslake_qa.bronze_qa.rawsales;
-- SELECT * FROM saleslake_prd.bronze_prd.rawsales;

------------3. Create Sales ---------------------

CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawsales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawsales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawsales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

------------4. Create Invoice ---------------------
CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/bronze/invoice/";

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/bronze/invoice/";

CREATE TABLE IF NOT EXISTS saleslake_prd.bronze_prd.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/bronze/invoice/";

----------------------- Silver layer Tables -------------------------

------------1. Select Sales ---------------------
-- SELECT * FROM saleslake_dev.silver_dev.cleanedsales;
-- SELECT * FROM saleslake_qa.silver_qa.cleanedsales;
-- SELECT * FROM saleslake_prd.silver_prd.cleanedsales;

------------1. Create Sales ---------------------
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

------------2. Select Customer ---------------------
-- SELECT * FROM saleslake_dev.silver_dev.cleanedcustomer;
-- SELECT * FROM saleslake_qa.silver_qa.cleanedcustomer;
-- SELECT * FROM saleslake_prd.silver_prd.cleanedcustomer;

------------2. Create Customer ---------------------
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

------------3. Create Invoice ---------------------
CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedinvoice (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/silver/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedinvoice (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/silver/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prd.silver_prd.cleanedinvoice (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/silver/invoice/';

----------------------------Gold Layer Table Creation ------------------------------
------------1. Select Sales ---------------------
-- SELECT * FROM saleslake_dev.gold_dev.refinedsales;
-- SELECT * FROM saleslake_qa.gold_qa.refinedsales;
-- SELECT * FROM saleslake_prd.gold_prd.refinedsales;

------------1. Create Sales ---------------------

CREATE OR REPLACE TABLE saleslake_dev.gold_dev.refinedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    initial_load_ts timestamp,
    last_updt_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.gold_qa.refinedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    initial_load_ts timestamp,
    last_updt_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.gold_prd.refinedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    initial_load_ts timestamp,
    last_updt_ts timestamp
);


------------2. Select Sales ---------------------
-- SELECT * FROM saleslake_dev.gold_dev.refinedcustomer;
-- SELECT * FROM saleslake_qa.gold_qa.refinedcustomer;
-- SELECT * FROM saleslake_prd.gold_prd.refinedcustomer;

------------2. Create Sales ---------------------
CREATE OR REPLACE TABLE saleslake_dev.gold_dev.refinedcustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);

CREATE OR REPLACE TABLE saleslake_qa.gold_qa.refinedcustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);

CREATE OR REPLACE TABLE saleslake_prd.gold_prd.refinedcustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);

CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.refinedinvoice (
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  is_active string,
  rec_version	int, 
  start_effective_ts	timestamp,
  end_effective_ts timestamp
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/gold/invoice/';

------------- Create all Catalog & Schemas -------------------
CREATE CATALOG IF NOT EXISTS saleslake_dev;
CREATE CATALOG IF NOT EXISTS saleslake_qa;
CREATE CATALOG IF NOT EXISTS saleslake_prd;

------------- dev Schema ------------
CREATE SCHEMA IF NOT EXISTS saleslake_dev.bronze_dev;
CREATE SCHEMA IF NOT EXISTS saleslake_dev.silver_dev;
CREATE SCHEMA IF NOT EXISTS saleslake_dev.gold_dev;

------------- qa Schema ------------
CREATE SCHEMA IF NOT EXISTS saleslake_qa.bronze_qa;
CREATE SCHEMA IF NOT EXISTS saleslake_qa.silver_qa;
CREATE SCHEMA IF NOT EXISTS saleslake_qa.gold_qa;

------------- prd Schema ------------
CREATE SCHEMA IF NOT EXISTS saleslake_prd.bronze_prd;
CREATE SCHEMA IF NOT EXISTS saleslake_prd.silver_prd;
CREATE SCHEMA IF NOT EXISTS saleslake_prd.gold_prd;

------------- Source File Location Volumn dev,qa,prd  ------------
CREATE VOLUME IF NOT EXISTS saleslake_dev.bronze_dev.vol_saleslake_src_files_dev;
CREATE VOLUME IF NOT EXISTS saleslake_qa.bronze_qa.vol_saleslake_src_files_qa;
CREATE VOLUME IF NOT EXISTS saleslake_prd.bronze_prd.vol_saleslake_src_files_prd;

------------- Archival File Location Volumn dev,qa,prd  ------------
CREATE VOLUME IF NOT EXISTS saleslake_dev.bronze_dev.vol_saleslake_archive_files_dev;
CREATE VOLUME IF NOT EXISTS saleslake_qa.bronze_qa.vol_saleslake_archive_files_qa;
CREATE VOLUME IF NOT EXISTS saleslake_prd.bronze_prd.vol_saleslake_archive_files_prd;


--------------------

----------------------- 1. Bronze layer Tables -------------------------
------------1. Select Customer ---------------------
-- SELECT * FROM saleslake_dev.bronze_dev.rawCustomer;
-- SELECT * FROM saleslake_qa.bronze_qa.rawCustomer;
-- SELECT * FROM saleslake_prd.bronze_prd.rawCustomer;
------------1. Create Customer ---------------------
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

----------------------- Bronze layer Tables -------------------------
------------2. Select Discount  ---------------------
-- SELECT * FROM saleslake_dev.bronze_dev.rawDiscount;
-- SELECT * FROM saleslake_qa.bronze_qa.rawDiscount;
-- SELECT * FROM saleslake_prd.bronze_prd.rawDiscount;

------------2. Select Discount ---------------------
CREATE TABLE saleslake_dev.bronze_dev.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING

);

CREATE TABLE saleslake_qa.bronze_qa.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING

);

CREATE TABLE saleslake_prd.bronze_prd.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING

);

----------------------- Bronze layer Tables -------------------------

------------Bronze Sales ---------------------
------------3. Select Sales  ---------------------
-- SELECT * FROM saleslake_dev.bronze_dev.rawsales;
-- SELECT * FROM saleslake_qa.bronze_qa.rawsales;
-- SELECT * FROM saleslake_prd.bronze_prd.rawsales;

------------3. Create Sales ---------------------

CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawsales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawsales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawsales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

------------4. Create Invoice ---------------------
CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/bronze/invoice/";

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/bronze/invoice/";

CREATE TABLE IF NOT EXISTS saleslake_prd.bronze_prd.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/bronze/invoice/";

----------------------- Silver layer Tables -------------------------

------------1. Select Sales ---------------------
-- SELECT * FROM saleslake_dev.silver_dev.cleanedsales;
-- SELECT * FROM saleslake_qa.silver_qa.cleanedsales;
-- SELECT * FROM saleslake_prd.silver_prd.cleanedsales;

------------1. Create Sales ---------------------
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

------------2. Select Customer ---------------------
-- SELECT * FROM saleslake_dev.silver_dev.cleanedcustomer;
-- SELECT * FROM saleslake_qa.silver_qa.cleanedcustomer;
-- SELECT * FROM saleslake_prd.silver_prd.cleanedcustomer;

------------2. Create Customer ---------------------
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

------------3. Create Invoice ---------------------
CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedinvoice (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/silver/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedinvoice (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/silver/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prd.silver_prd.cleanedinvoice (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/silver/invoice/';

----------------------------Gold Layer Table Creation ------------------------------
------------1. Select Sales ---------------------
-- SELECT * FROM saleslake_dev.gold_dev.refinedsales;
-- SELECT * FROM saleslake_qa.gold_qa.refinedsales;
-- SELECT * FROM saleslake_prd.gold_prd.refinedsales;

------------1. Create Sales ---------------------

CREATE OR REPLACE TABLE saleslake_dev.gold_dev.refinedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    initial_load_ts timestamp,
    last_updt_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_qa.gold_qa.refinedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    initial_load_ts timestamp,
    last_updt_ts timestamp
);

CREATE OR REPLACE TABLE saleslake_prd.gold_prd.refinedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    initial_load_ts timestamp,
    last_updt_ts timestamp
);


------------2. Select Sales ---------------------
-- SELECT * FROM saleslake_dev.gold_dev.refinedcustomer;
-- SELECT * FROM saleslake_qa.gold_qa.refinedcustomer;
-- SELECT * FROM saleslake_prd.gold_prd.refinedcustomer;

------------2. Create Sales ---------------------
CREATE OR REPLACE TABLE saleslake_dev.gold_dev.refinedcustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);

CREATE OR REPLACE TABLE saleslake_qa.gold_qa.refinedcustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);

CREATE OR REPLACE TABLE saleslake_prd.gold_prd.refinedcustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);

CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.refinedinvoice (
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  is_active string,
  rec_version	int, 
  start_effective_ts	timestamp,
  end_effective_ts timestamp
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/gold/invoice/';


CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.refinedinvoice (
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  is_active string,
  rec_version	int, 
  start_effective_ts	timestamp,
  end_effective_ts timestamp
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/gold/invoice/';


CREATE TABLE IF NOT EXISTS saleslake_prd.gold_prd.refinedinvoice (
  customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  is_active string,
  rec_version	int, 
  start_effective_ts	timestamp,
  end_effective_ts timestamp
)
USING DELTA
LOCATION 's3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/gold/invoice/';
