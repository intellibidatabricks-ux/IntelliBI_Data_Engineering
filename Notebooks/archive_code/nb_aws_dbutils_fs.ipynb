# %%
dbutils.fs.ls("s3://saleslake-748005667258-eu-north-1-an/saleslake/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/")

# %%
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/")
# ---------------
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/archive_files/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/archive_files/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/archive_files/")

# %%
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/")

# %%
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/bronze/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/silver/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/gold/")

dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/bronze/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/silver/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/gold/")

dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/bronze/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/silver/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/gold/")

# %%
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/bronze/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/silver/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/gold/")

dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/bronze/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/silver/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/gold/")

dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/bronze/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/silver/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/gold/")

# %%
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/gold/invoice/")

dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/gold/invoice/")

dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/gold/invoice/")

# %%
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/gold/invoice/")
#
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/delta_tables/gold/invoice/")
#
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/delta_tables/gold/invoice/")
